# %% [markdown]
# ### House Prices Prediction

# %% [markdown]
# #### Reading the training set

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

#read the train data
train = pd.read_csv('../input/train.csv')

train.shape
# Out:
# (1460, 81)

# %% [markdown]
# #### Description of the training set

# %%
#Find the info on categorical and continuous variables
train.describe(include=['O'])
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1      ...      GarageType  \
# count       1460         1460       1460      ...            1379
# unique         3           25          9      ...               6
# top          Gtl        NAmes       Norm      ...          Attchd
# freq        1382          225       1260      ...             870
#
#        GarageFinish GarageQual GarageCond PavedDrive PoolQC  Fence  \
# count          1379       1379       1379       1460      7    281
# unique            3          5          5          3      3      4
# top             Unf         TA         TA          Y     Gd  MnPrv
# ...

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %% [markdown]
# #### Dropping all the columns which have null values more than 30% of total size of data set

# %%
#Drop the columns having null values more than 30% of size of dataset
train1 = train.copy()
for column in train1.columns :
    if train1[column].isnull().sum() > 500:
        train1 = train1.drop([column],axis=1)
train1.shape
# Out:
# (1460, 76)

# %% [markdown]
# #### Filling the Categorical columns missing values with the mode of the variable and numerical with the mean

# %%
#Impute the columns having lesser number of missing values
for column in train1.columns :
    if train1[column].isnull().sum() < 500 and train1[column].isnull().sum() != 0:
        #print(column)
        if train1[column].dtype == "object":
            #print(train1[column].dtype)
            temp = train1[column].mode()
            train1[column] = train1[column].fillna(value = temp[0])
        else:
            train1[column] = train1[column].fillna(value = train1[column].mean())

# %% [markdown]
# #### Target Variable

# %%
#Obtaining the target variable
train_Y = train1.SalePrice

# %%
#The train set
train1 = train1.drop(['SalePrice'],axis = 1)

# %% [markdown]
# #### Original encoding the target variables

# %%
for variable in train1.columns: # Loop through all columns in the dataframe
    if train1[variable].dtype == 'object': # Only apply for columns with categorical strings
        train1[variable] = pd.Categorical(train1[variable]).codes # Replace strings with an integer
train1.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0   1          60         3         65.0     8450       1         3
# 1   2          20         3         80.0     9600       1         3
# 2   3          60         3         68.0    11250       1         0
# 3   4          70         3         60.0     9550       1         0
# 4   5          60         3         84.0    14260       1         0
#
#    LandContour  Utilities  LotConfig      ...        OpenPorchSF  \
# 0            3          0          4      ...                 61
# 1            3          0          2      ...                  0
# 2            3          0          4      ...                 42
# 3            3          0          0      ...                 35
# 4            3          0          2      ...                 84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# 0              0          0            0         0        0       2    2008
# ...

# %% [markdown]
# #### Splitting the data into train and test for model analysis

# %%
#Splitting the train and test data set using train_test_split
from sklearn.model_selection import train_test_split

train_X, test_X, train_y, test_y = train_test_split(train1,train_Y, test_size = 0.20, random_state = 47)

# %% [markdown]
# #### Decision Tree Regressor Model

# %%
#using decision tree for prediction
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
def getMae(max_leaf_nodes, train_X,test_X, train_Y, test_Y):
    model = DecisionTreeRegressor()
    
    model.fit(train_X, train_Y)
    predicted_values = model.predict(test_X)
    mae = mean_absolute_error(test_Y,predicted_values )
    return mae

# %%
for leaf in [5,50,500,5000]:
    mae = getMae(leaf,train_X,test_X, train_y, test_y)
    print("leaf : %d \t\t Mae : %d" %(leaf,mae))
# Out:
# leaf : 5 		 Mae : 27019
# leaf : 50 		 Mae : 26856
# leaf : 500 		 Mae : 26449
# leaf : 5000 		 Mae : 27885

# %% [markdown]
# #### Random Forest Model

# %%
#using random forest to do the prediction
from sklearn.ensemble import RandomForestRegressor
def getMaeforRandomForest(train_X,test_X, train_Y, test_Y):
    model = RandomForestRegressor()
    
    model.fit(train_X, train_Y)
    predicted_values = model.predict(test_X)
    mae = mean_absolute_error(test_Y,predicted_values )
    return mae

# %%
mae = getMaeforRandomForest(train_X,test_X, train_y, test_y)
print("random Forest Mae : %d" %(mae))
# Out:
# random Forest Mae : 22306

# %% [markdown]
# #### XGBoost Model

# %%
#Gradient Boosting for prediction
from xgboost import XGBRegressor
def getMaeforXGBoost(n_estimators,train_X,test_X, train_Y, test_Y):
    model = XGBRegressor(n_estimators = n_estimators)
    
    model.fit(train_X, train_Y, early_stopping_rounds=5, eval_set=[(test_X, test_Y)],verbose=False)
    predicted_values = model.predict(test_X)
    mae = mean_absolute_error(test_Y,predicted_values )
    return mae

# %%
for estimators in [100,500,1000,1500]:
    mae = getMaeforXGBoost(estimators,train_X,test_X, train_y, test_y)
    print("Estimator : %d \t\t Mae : %d" %(estimators,mae))
# Out:
# Estimator : 100 		 Mae : 21184
# Estimator : 500 		 Mae : 21184
# Estimator : 1000 		 Mae : 21184
# Estimator : 1500 		 Mae : 21184

# %% [markdown]
# #### Reading the test prediction data

# %%
### Encoding the test set
test = pd.read_csv('../input/test.csv')

# %%
#Drop the columns having null values more than 30% of size of dataset
test1 = test.copy()
for column in test1.columns :
    if test1[column].isnull().sum() > 500:
        test1 = test1.drop([column],axis=1)
test1.shape
# Out:
# (1459, 75)

# %% [markdown]
# #### Performing the same data transformation as train to test

# %%
#Impute the columns having lesser number of missing values
for column in test1.columns :
    if test1[column].isnull().sum() < 500 and test1[column].isnull().sum() != 0:
        #print(column)
        if test1[column].dtype == "object":
            temp = test1[column].mode()
            test1[column] = test1[column].fillna(value = temp[0])
        else:
            test1[column] = test1[column].fillna(value = test1[column].mean())

# %%
for variable in test1.columns: # Loop through all columns in the dataframe
    if test1[variable].dtype == 'object': # Only apply for columns with categorical strings
        test1[variable] = pd.Categorical(test1[variable]).codes # Replace strings with an integer
test1.head()
# Out:
#      Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0  1461          20         2         80.0    11622       1         3
# 1  1462          20         3         81.0    14267       1         0
# 2  1463          60         3         74.0    13830       1         0
# 3  1464          60         3         78.0     9978       1         0
# 4  1465         120         3         43.0     5005       1         0
#
#    LandContour  Utilities  LotConfig      ...        OpenPorchSF  \
# 0            3          0          4      ...                  0
# 1            3          0          0      ...                 36
# 2            3          0          4      ...                 34
# 3            3          0          4      ...                 36
# 4            1          0          4      ...                 82
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %% [markdown]
# ### Applying the XGBRegressor which has the least mean absolute error

# %%
#building the model
model = XGBRegressor(n_estimators = 1000)
model.fit(train1, train_Y, early_stopping_rounds=5, eval_set=[(test_X, test_y)],verbose=False)
predicted_values = model.predict(test1)

# %%
pred_df = pd.DataFrame(predicted_values, index=test1["Id"], columns=["SalePrice"])
pred_df.to_csv('submission.csv', header=True, index_label='Id')
